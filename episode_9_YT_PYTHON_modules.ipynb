# %% [markdown]
# <a href="https://colab.research.google.com/github/juniorhuttonaddy09/juniors-python-progress/blob/main/episode_9_YT_PYTHON_modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# had trouble with understanding this code although it was done, still having. trouble

print('Imported my_module...')

test = 'Test String'


def find_index(to_search, target):
    '''Find the index of a value in a sequence'''
    for i, value in enumerate(to_search):
        if value == target:
            return i

    return -1
# Out:
# Imported my_module...
